# %%
import torch, torchvision
from torch.nn import Sequential, Flatten, Linear, ReLU, CrossEntropyLoss
import json
import matplotlib.pyplot as plt

with open("config.json") as file:
    config = json.load(file)

label_map = {
    0 : "T-shirt/top", 1 : "Trousers", 2 : "Pullover", 3 : "Dress", 4 : "Coat",
    5 : "Sandal", 6 : "Shirt", 7 : "Sneaker", 8 : "Bag", 9 : "Ankle boot"
}

# %%
train_data = torchvision.datasets.FashionMNIST("../data", transform=torchvision.transforms.ToTensor(), download=True)
test_data = torchvision.datasets.FashionMNIST("../data", transform=torchvision.transforms.ToTensor(), train=False, download=True)

data_loader_train = torch.utils.data.DataLoader(train_data, batch_size=config["batch_size"])
data_loader_test = torch.utils.data.DataLoader(test_data, batch_size=config["batch_size"])

# %%
device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")
model = Neural_Network.to(device)
optimizer = torch.optim.SGD(params = model.parameters())
loss_fn = CrossEntropyLoss()
# Out:
# Using cpu device
